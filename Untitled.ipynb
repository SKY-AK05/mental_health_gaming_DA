# %%
import pandas as pd

df = pd.read_csv("Gaming and Mental Health.csv")

df.head()
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre    primary_game  \
# 0    GD0001   17    Male                11.1   Mobile Games  Clash of Clans
# 1    GD0002   21    Male                 3.0           MOBA          Dota 2
# 2    GD0003   23    Male                 7.6            FPS           CS:GO
# 3    GD0004   20  Female                 7.2            RPG          Skyrim
# 4    GD0005   18    Male                 6.8  Battle Royale    Apex Legends
#
#   gaming_platform  sleep_hours sleep_quality sleep_disruption_frequency  ...  \
# 0              PC          3.7     Very Poor                  Sometimes  ...
# 1              PC          7.2          Fair                     Rarely  ...
# 2  Multi-platform          4.4          Fair                      Often  ...
# 3  Multi-platform          5.1          Fair                      Often  ...
# 4              PC          3.4          Poor                      Never  ...
#
# ...

# %%
df.columns
# Out:
# Index(['record_id', 'age', 'gender', 'daily_gaming_hours', 'game_genre',
#        'primary_game', 'gaming_platform', 'sleep_hours', 'sleep_quality',
#        'sleep_disruption_frequency', 'academic_work_performance', 'grades_gpa',
#        'work_productivity_score', 'mood_state', 'mood_swing_frequency',
#        'withdrawal_symptoms', 'loss_of_other_interests',
#        'continued_despite_problems', 'eye_strain', 'back_neck_pain',
#        'weight_change_kg', 'exercise_hours_weekly', 'social_isolation_score',
#        'face_to_face_social_hours_weekly', 'monthly_game_spending_usd',
#        'years_gaming', 'gaming_addiction_risk_level'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# record_id                             0
# age                                   0
# gender                                0
# daily_gaming_hours                    0
# game_genre                            0
# primary_game                          0
# gaming_platform                       0
# sleep_hours                           0
# sleep_quality                         0
# sleep_disruption_frequency            0
# academic_work_performance             0
# grades_gpa                          246
# work_productivity_score             326
# mood_state                            0
# mood_swing_frequency                  0
# withdrawal_symptoms                   0
# loss_of_other_interests               0
# continued_despite_problems            0
# eye_strain                            0
# back_neck_pain                        0
# weight_change_kg                      0
# exercise_hours_weekly                 0
# social_isolation_score                0
# ...

# %%
df[df['grades_gpa'].isnull()][['record_id', 'age', 'grades_gpa']].head(20)
# Out:
#    record_id  age  grades_gpa
# 2     GD0003   23         NaN
# 7     GD0008   28         NaN
# 12    GD0013   28         NaN
# 15    GD0016   25         NaN
# 40    GD0041   33         NaN
# 45    GD0046   26         NaN
# 47    GD0048   29         NaN
# 50    GD0051   24         NaN
# 56    GD0057   24         NaN
# 57    GD0058   25         NaN
# 58    GD0059   23         NaN
# 59    GD0060   33         NaN
# 64    GD0065   26         NaN
# 66    GD0067   23         NaN
# 70    GD0071   25         NaN
# 71    GD0072   23         NaN
# 75    GD0076   33         NaN
# 84    GD0085   26         NaN
# 92    GD0093   26         NaN
# 97    GD0098   23         NaN

# %%
df['age_group'] = df['age'].apply(lambda x: 'Student' if x <= 22 else 'Adult')

# %%
df.head()
# Out:
#   record_id  age  gender  daily_gaming_hours     game_genre    primary_game  \
# 0    GD0001   17    Male                11.1   Mobile Games  Clash of Clans
# 1    GD0002   21    Male                 3.0           MOBA          Dota 2
# 2    GD0003   23    Male                 7.6            FPS           CS:GO
# 3    GD0004   20  Female                 7.2            RPG          Skyrim
# 4    GD0005   18    Male                 6.8  Battle Royale    Apex Legends
#
#   gaming_platform  sleep_hours sleep_quality sleep_disruption_frequency  ...  \
# 0              PC          3.7     Very Poor                  Sometimes  ...
# 1              PC          7.2          Fair                     Rarely  ...
# 2  Multi-platform          4.4          Fair                      Often  ...
# 3  Multi-platform          5.1          Fair                      Often  ...
# 4              PC          3.4          Poor                      Never  ...
#
# ...

# %%
df['age'].describe()
# Out:
# count    1000.000000
# mean       20.475000
# std         4.116105
# min        13.000000
# 25%        18.000000
# 50%        20.000000
# 75%        22.000000
# max        35.000000
# Name: age, dtype: float64

# %%
# Out:
#     record_id  age  gender  daily_gaming_hours     game_genre  \
# 128    GD0129   35    Male                 3.1           MOBA
# 409    GD0410   35  Female                 3.1  Battle Royale
# 625    GD0626   35    Male                 6.9       Strategy
#
#           primary_game gaming_platform  sleep_hours sleep_quality  \
# 128  League of Legends         Console          7.6          Good
# 409            Warzone          Mobile          7.1          Fair
# 625       StarCraft II          Mobile          5.2     Very Poor
#
#     sleep_disruption_frequency  ... eye_strain  back_neck_pain  \
# 128                     Always  ...      False           False
# 409                  Sometimes  ...      False           False
# 625                      Often  ...       True           False
#
#      weight_change_kg exercise_hours_weekly social_isolation_score  \
# 128               1.8                   7.8                      3
# ...

# %%
# !pip install psycopg2-binary sqlalchemy

# %%
from sqlalchemy import create_engine

# Step 1: Connect to PostgreSQL
# Replace placeholders with your actual details
username = "postgres"      # default user
password = "root" # the password you set during installation
host = "localhost"         # if running locally
port = "5432"              # default PostgreSQL port
database = "game"    # the database you created in pgAdmin

engine = create_engine(f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}")

# Step 2: Load DataFrame into PostgreSQL
table_name = "MHgames"   # choose any table name
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in database '{database}'.")
# Out:
# Data successfully loaded into table 'MHgames' in database 'game'.

# %%
from supabase import create_client

url = "https://rzkfflygspmeocogixqa.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InJ6a2ZmbHlnc3BtZW9jb2dpeHFhIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc3MTQyNTcxNCwiZXhwIjoyMDg3MDAxNzE0fQ.R5sRaT_pNa-scIByEBbNk3TwaTkRsPX6O267uN0vDps"   # use service key for inserts

supabase = create_client(url, key)

data = df.to_dict(orient="records")

response = supabase.table("mhgames").insert(data).execute()

print(response)


print(f"Data successfully loaded into table '{table_name}' in Supabase.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 10
#       6 supabase = create_client(url, key)
#       8 data = df.to_dict(orient="records")
# ---> 10 response = supabase.table("mhgames").insert(data).execute()
#      12 print(response)
#      15 print(f"Data successfully loaded into table '{table_name}' in Supabase.")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\postgrest\_sync\request_builder.py:47, in SyncQueryRequestBuilder.execute(self)
#      35 def execute(self) -> APIResponse:
#      36     """Execute the query.
#      37
#      38     .. tip::
#    (...)     45         :class:`APIError` If the API raised an error.
#      46     """
# ---> 47     r = self.request.send()
#      48     try:
#      49         if r.is_success:
#
# ...

# %%
df.to_csv("mhgames.csv", index=False)

# %%
pip install supabase
# Out:
# ...
#   Using cached realtime-2.28.0-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached supabase_functions-2.28.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached supabase_auth-2.28.0-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# ...
#   Using cached pyiceberg-0.11.0-cp313-cp313-win_amd64.whl.metadata (4.9 kB)
# ...
#   Using cached StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached mmh3-5.2.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached strictyaml-1.7.3-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached pyroaring-1.0.3-cp313-cp313-win_amd64.whl.metadata (10 kB)
# ...
# Using cached realtime-2.28.0-py3-none-any.whl (22 kB)
# ...
